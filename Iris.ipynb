# %%
import numpy as np
import pandas as pd
from sklearn.datasets import load_iris
import matplotlib.pyplot as plt
import warnings
import seaborn as sns
# %matplotlib inline
warnings.filterwarnings(action='ignore') 
sns.set_palette("pastel")
sns.set(style='whitegrid')

# %%
iris = load_iris()
df = pd.DataFrame(iris.data, columns=iris.feature_names)
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
df['species'] = iris.target
df['species'] = df['species'].map({0:'seotsa', 1:'versicolor', 2:'virginica'})
df.columns = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'species']
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  seotsa
# 1           4.9          3.0           1.4          0.2  seotsa
# 2           4.7          3.2           1.3          0.2  seotsa
# 3           4.6          3.1           1.5          0.2  seotsa
# 4           5.0          3.6           1.4          0.2  seotsa

# %%
df['species'].value_counts()
# Out:
# seotsa        50
# versicolor    50
# virginica     50
# Name: species, dtype: int64

# %%
df.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
print(df.describe().T)
# Out:
#               count      mean       std  min  25%   50%  75%  max
# sepal_length  150.0  5.843333  0.828066  4.3  5.1  5.80  6.4  7.9
# sepal_width   150.0  3.057333  0.435866  2.0  2.8  3.00  3.3  4.4
# petal_length  150.0  3.758000  1.765298  1.0  1.6  4.35  5.1  6.9
# petal_width   150.0  1.199333  0.762238  0.1  0.3  1.30  1.8  2.5

# %%
sns.scatterplot(data = df, x="sepal_length", y="sepal_width", hue="species")
plt.show()

# %%
sns.scatterplot(data = df, x="petal_length", y="petal_width", hue="species")
plt.show()

# %%
sns.boxplot(data = df, x="species", y="sepal_length")
plt.show()

# %%
sns.boxplot(data = df, x="species", y="sepal_length")
sns.stripplot(data = df, x="species", y="sepal_length", jitter=True, linewidth=1)
plt.show()

# %%
sns.boxplot(data = df, x="species", y="sepal_width")
plt.show()

# %%
sns.boxplot(data = df, x="species", y="sepal_width")
sns.stripplot(data = df, x="species", y="sepal_width", jitter=True, linewidth=1)
plt.show()

# %%
sns.boxplot(data = df, x="species", y="petal_length")
plt.show()

# %%
sns.boxplot(data = df, x="species", y="petal_length")
sns.stripplot(data = df, x="species", y="petal_length", jitter=True, linewidth=1)
plt.show()

# %%
sns.boxplot(data = df, x="species", y="petal_width")
plt.show()

# %%
sns.boxplot(data = df, x="species", y="petal_width")
sns.stripplot(data = df, x="species", y="petal_width", jitter=True, linewidth=1)
plt.show()

# %%
sns.heatmap(df.corr(), annot=True, square=True, cmap="GnBu", vmin=-1, vmax=1, linewidths=3)
plt.title("Correlation")
plt.show()

# %%
sns.pairplot(df, hue='species', size=5)
plt.show()

# %%
sns.lmplot(data= df,x='sepal_width', y='sepal_length', hue='species')
plt.show()

# %%
sns.lmplot(data= df,x='petal_width', y='petal_length', hue='species')
plt.show()
